# %%
import numpy as np
import matplotlib.pyplot as plt

# Definiere eine Funktion zur Berechnung von kubischen Splines
def cubic_spline(x, y):
    n = len(x)
    h = np.diff(x)
    alpha = np.zeros(n-1)
    for i in range(1, n-1):
        alpha[i] = 3/h[i]*(y[i+1]-y[i]) - 3/h[i-1]*(y[i]-y[i-1])
    
    l = np.zeros(n)
    mu = np.zeros(n)
    z = np.zeros(n)
    l[0] = 1
    mu[0] = z[0] = 0
    
    for i in range(1, n-1):
        l[i] = 2*(x[i+1]-x[i-1])-h[i-1]*mu[i-1]
        mu[i] = h[i]/l[i]
        z[i] = (alpha[i]-h[i-1]*z[i-1])/l[i]
    
    l[n-1] = 1
    z[n-1] = 0
    c = np.zeros(n)
    b = np.zeros(n-1)
    d = np.zeros(n-1)
        
    for j in range(n-2, -1, -1):
        c[j] = z[j] - mu[j]*c[j+1]
        b[j] = (y[j+1]-y[j])/h[j] - h[j]*(c[j+1]+2*c[j])/3
        d[j] = (c[j+1]-c[j])/(3*h[j])
    
    return y, b, c, d


# Input der Rohdaten
t = np.array([0, 1, 2, 3, 4, 5])
x = np.array([4, 2, 4, 8, 6, 10])
y = np.array([2, 1, 2, 4, 3, 5])

# Plot der Rohdaten und des kubischen Splines
x_interp, bx, cx, dx = cubic_spline(t, x)
y_interp, by, cy, dy = cubic_spline(t, y)
t_new = np.linspace(t[0], t[-1], 100)


x_new = np.zeros(len(t_new))
for i in range(len(t_new)):
    for j in range(len(t)-1):
        if t[j] <= t_new[i] <= t[j+1]:
            x_new[i] = x_interp[j] + bx[j]*(t_new[i]-t[j]) + cx[j]*(t_new[i]-t[j])**2 + dx[j]*(t_new[i]-t[j])**3
            break
y_new = np.zeros(len(t_new))
for i in range(len(t_new)):
    for j in range(len(t)-1):
        if t[j] <= t_new[i] <= t[j+1]:
            y_new[i] = y_interp[j] + by[j]*(t_new[i]-t[j]) + cy[j]*(t_new[i]-t[j])**2 + dy[j]*(t_new[i]-t[j])**3
            break

plt.plot(t, x, 'o', label='x-Rohdaten')
plt.plot(t, y, 'o', label='x-Rohdaten')
plt.plot(t_new, x_new, label='x-Spline-Interpolation')
plt.plot(t_new, y_new, label='y-Spline-Interpolation')
plt.legend()
plt.show()
